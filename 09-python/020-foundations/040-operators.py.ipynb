# %%
a = 2
b = 3

# %%
# addition
a + b
# Out:
# 5

# %%
# subtraction
a - b
# Out:
# -1

# %%
# multiplication
a * b
# Out:
# 6

# %%
# division
a / b
# Out:
# 0.6666666666666666

# %%
# floor division
a // b
# Out:
# 0

# %%
# modulus
a % b
# Out:
# 2

# %%
# exponentiation
a ** b
# Out:
# 8
